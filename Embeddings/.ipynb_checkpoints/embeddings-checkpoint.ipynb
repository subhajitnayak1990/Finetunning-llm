# %%
from rich import print
# Out:
# Running cells with 'venvembeddings (3.8.8) (Python 3.8.8)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/subha/Projects/Finetunning-llm/venvembeddings/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
